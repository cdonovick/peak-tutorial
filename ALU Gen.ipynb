# %%
import peak
import hwtypes as hw

from peak import Peak, family_closure
from hwtypes.adt import Enum, Tuple

# %%
def alugen(op_map, num_ports, datawidth):
    class Opcode(Enum):
        Add = Enum.Auto()
        Sub = Enum.Auto()
        Neg = Enum.Auto()

    @family_closure
    def ALU_fc(family):
        Word = family.BitVector[datawidth]
        Bit = family.Bit
        T = family.get_constructor(Tuple[Word, Word, Word])

        @family.assemble(locals(), globals())
        class ALU(Peak):
            def __call__(self, inst: Opcode, inputs: T) -> Word:
                if inst == Opcode.Add:
                    return inputs[0] + inputs[1] + inputs[2]
                elif inst == Opcode.Sub:
                    return inputs[0] - inputs[2]
                else:
                    return -inputs[1]

        return ALU

    return Opcode, ALU_fc


def add3(a, b, c):
    return a + b + c


def sub(a, b):
    return a - b


def neg(a):
    return -a


NUM_INPUTS = 3
DATA_WIDTH = 16

OP_MAP = {
    'Add': (add3, (0, 1, 2)),
    'Sub': (sub, (0, 2)),
    'Neg': (neg, (1, )),
}

Opcode, ALU_fc = alugen(OP_MAP, NUM_INPUTS, DATA_WIDTH)

assert hasattr(Opcode, 'Add')
assert hasattr(Opcode, 'Sub')
assert hasattr(Opcode, 'Neg')

DataT = Tuple[hw.BitVector[16], hw.BitVector[16], hw.BitVector[16]]

ALU = ALU_fc.Py # ALU_fc(peak.family.PyFamily())

alu = ALU()

for _ in range(256):
    a = hw.BitVector.random(16)
    b = hw.BitVector.random(16)
    c = hw.BitVector.random(16)
    inputs = DataT(a, b, c)

    assert alu(Opcode.Add, inputs) == a + b + c
    assert alu(Opcode.Sub, inputs) == a - c
    assert alu(Opcode.Neg, inputs) == -b

# %%
#Hwtypes impl

def alugen(op_map, num_ports, datawidth):
    assert op_map  # len(op_map) > 0
    Opcode = type(Enum)('Opcode', (Enum, ), {k: Enum.Auto() for k in op_map})

    @family_closure
    def ALU_fc(family):
        Word = family.BitVector[datawidth]
        Bit = family.Bit
        T = family.get_constructor(Tuple[(Word for _ in range(num_ports))])

        def _build_ite(op_map, inst, inputs):
            term = None
            for op_name in reversed(op_map):
                f, op_indices = op_map[op_name]
                if term is None:
                    term = f(*(inputs[idx] for idx in op_indices))
                else:
                    op_enum = getattr(Opcode, op_name)
                    term = Bit(
                        op_enum == inst
                    ).ite(f(*(inputs[idx] for idx in op_indices)), term)
            assert term is not None
            return term

        @family.assemble(locals(), globals())
        class ALU(Peak):
            def __call__(self, inst: Opcode, inputs: T) -> Word:
                return _build_ite(op_map, inst, inputs)

        return ALU

    return Opcode, ALU_fc


def add3(a, b, c):
    return a + b + c


def sub(a, b):
    return a - b


def neg(a):
    return -a


NUM_INPUTS = 3
DATA_WIDTH = 16

OP_MAP = {
    'Add': (add3, (0, 1, 2)),
    'Sub': (sub, (0, 2)),
    'Neg': (neg, (1, )),
}

Opcode, ALU_fc = alugen(OP_MAP, NUM_INPUTS, DATA_WIDTH)

assert hasattr(Opcode, 'Add')
assert hasattr(Opcode, 'Sub')
assert hasattr(Opcode, 'Neg')

DataT = Tuple[hw.BitVector[16], hw.BitVector[16], hw.BitVector[16]]

ALU = ALU_fc.Py

alu = ALU()

for _ in range(256):
    a = hw.BitVector.random(16)
    b = hw.BitVector.random(16)
    c = hw.BitVector.random(16)
    inputs = DataT(a, b, c)

    assert alu(Opcode.Add, inputs) == a + b + c
    assert alu(Opcode.Sub, inputs) == a - c
    assert alu(Opcode.Neg, inputs) == -b

# %%
#using ast_tools
import ast_tools
from ast_tools.passes import apply_passes, loop_unroll

# %%
def alugen(op_map, num_ports, datawidth):
    assert op_map  # len(op_map) > 0

    Opcode = type(Enum)('Opcode', (Enum, ), {k: Enum.Auto() for k in op_map})

    @family_closure
    def ALU_fc(family):
        Word = family.BitVector[datawidth]
        Bit = family.Bit
        T = family.get_constructor(Tuple[(Word for _ in range(num_ports))])
        op_names = list(reversed(op_map))

        def build_args(inputs, op_indices):
            return (inputs[idx] for idx in op_indices)

        @family.assemble(locals(), globals())
        class ALU(Peak):
            @apply_passes([loop_unroll()])
            def __call__(self, inst: Opcode, inputs: T) -> Word:
                res = Word(0)

                for i in ast_tools.macros.unroll(range(len(op_names))):
                    op_name = op_names[i]
                    f, op_indices = op_map[op_name]
                    op_enum = getattr(Opcode, op_name)
                    if op_enum == inst:
                        res = f(*build_args(inputs, op_indices))
                return res

        return ALU

    return Opcode, ALU_fc


def add3(a, b, c):
    return a + b + c


def sub(a, b):
    return a - b


def neg(a):
    return -a


NUM_INPUTS = 3
DATA_WIDTH = 16

OP_MAP = {
    'Add': (add3, (0, 1, 2)),
    'Sub': (sub, (0, 2)),
    'Neg': (neg, (1, )),
}

Opcode, ALU_fc = alugen(OP_MAP, NUM_INPUTS, DATA_WIDTH)

assert hasattr(Opcode, 'Add')
assert hasattr(Opcode, 'Sub')
assert hasattr(Opcode, 'Neg')

DataT = Tuple[hw.BitVector[16], hw.BitVector[16], hw.BitVector[16]]

ALU = ALU_fc.Py
alu = ALU()

for _ in range(256):
    a = hw.BitVector.random(16)
    b = hw.BitVector.random(16)
    c = hw.BitVector.random(16)
    inputs = DataT(a, b, c)

    assert alu(Opcode.Add, inputs) == a + b + c
    assert alu(Opcode.Sub, inputs) == a - c
    assert alu(Opcode.Neg, inputs) == -b

# %%
def alugen(op_map, num_ports, datawidth):
    assert op_map  # len(op_map) > 0
    Opcode = type(Enum)('Opcode', (Enum, ), {k: Enum.Auto() for k in op_map})

    @family_closure
    def ALU_fc(family):
        Word = family.BitVector[datawidth]
        Bit = family.Bit
        T = family.get_constructor(Tuple[(Word for _ in range(num_ports))])
        op_names = list(reversed(op_map))

        def build_args(inputs, op_indices):
            return (inputs[idx] for idx in op_indices)

        @family.assemble(locals(), globals())
        class ALU(Peak):
            @apply_passes([loop_unroll()])
            def __call__(self, inst: Opcode, inputs: T) -> Word:
                op_name = op_names[0]
                f, op_indices = op_map[op_name]
                op_enum = getattr(Opcode, op_name)
                res = f(*build_args(inputs, op_indices))

                for i in ast_tools.macros.unroll(range(1, len(op_names))):
                    op_name = op_names[i]
                    f, op_indices = op_map[op_name]
                    op_enum = getattr(Opcode, op_name)
                    if op_enum == inst:
                        res = f(*build_args(inputs, op_indices))
                return res

        return ALU

    return Opcode, ALU_fc


def add3(a, b, c):
    return a + b + c


def sub(a, b):
    return a - b


def neg(a):
    return -a


NUM_INPUTS = 3
DATA_WIDTH = 16

OP_MAP = {
    'Add': (add3, (0, 1, 2)),
    'Sub': (sub, (0, 2)),
    'Neg': (neg, (1, )),
}

Opcode, ALU_fc = alugen(OP_MAP, NUM_INPUTS, DATA_WIDTH)

assert hasattr(Opcode, 'Add')
assert hasattr(Opcode, 'Sub')
assert hasattr(Opcode, 'Neg')

DataT = Tuple[hw.BitVector[16], hw.BitVector[16], hw.BitVector[16]]

ALU = ALU_fc.Py
alu = ALU()

for _ in range(256):
    a = hw.BitVector.random(16)
    b = hw.BitVector.random(16)
    c = hw.BitVector.random(16)
    inputs = DataT(a, b, c)

    assert alu(Opcode.Add, inputs) == a + b + c
    assert alu(Opcode.Sub, inputs) == a - c
    assert alu(Opcode.Neg, inputs) == -b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 69>()
#      72 c = hw.BitVector.random(16)
#      73 inputs = DataT(a, b, c)
# ---> 75 assert alu(Opcode.Add, inputs) == a + b + c
#      76 assert alu(Opcode.Sub, inputs) == a - c
#      77 assert alu(Opcode.Neg, inputs) == -b
#
# File ~/work/peak-tutorial/.ast_tools/__call__140609109622336.py:5, in __call__(self, inst, inputs)
#       3 f, op_indices = op_map[op_name]
#       4 op_enum = getattr(Opcode, op_name)
# ----> 5 res = f(*build_args(inputs, op_indices))
#       6 op_name = op_names[1]
#       7 f, op_indices = op_map[op_name]
#
# TypeError: __main__.neg() argument after * must be an iterable, not NoneType

# %%
import pysmt
from pysmt import shortcuts as sc

sf = peak.family.SMTFamily()

DataT = Tuple[sf.BitVector[16], sf.BitVector[16], sf.BitVector[16]]
asm_add = sf.get_adt_t(Opcode)(Opcode.Add)

ALU = ALU_fc.SMT
assert ALU is ALU_fc(sf)
alu = ALU()

a = sf.BitVector[16]()
b = sf.BitVector[16]()
c = sf.BitVector[16]()

res = alu(asm_add, DataT(a, b, c))

with sc.Solver('z3') as s:
    s.add_assertion((res != a + b + c).value)
    if s.solve():
        print('res != a + b + c')
        print(f'a = {s.get_value(a.value)}')
        print(f'b = {s.get_value(b.value)}')
        print(f'c = {s.get_value(c.value)}')
    else:
        print('verified')
# Out:
# Traceback (most recent call last):
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/ssa.py:558 in leave_Name
#     return cst.Name(self.name_table[name])
#
#   File /usr/lib/python3.10/collections/__init__.py:986 in __getitem__
#     return self.__missing__(key)            # support subclasses that define __missing__
#
#   File /usr/lib/python3.10/collections/__init__.py:978 in __missing__
#     raise KeyError(key)
#
# KeyError: 'idx'
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [14] in <cell line: 9>
#     ALU = ALU_fc.SMT
#
#   File ~/work/peak/peak/features.py:123 in SMT
#     return self(self.family.SMTFamily())
#
#   File ~/work/peak/peak/features.py:141 in __call__
#     res = self.fc(*args, **kwargs)
#
#   Input In [13] in ALU_fc
#     class ALU(Peak):
#
#   File ~/work/peak/peak/family.py:318 in deco
#     cls = s_deco(cls)
#
#   File ~/work/peak/peak/family.py:23 in wrapped
#     return f(g(*args, **kwargs))
#
#   File ~/work/peak/peak/family.py:283 in deco
#     cls = s_deco(cls)
#
#   File ~/work/peak/peak/family.py:23 in wrapped
#     return f(g(*args, **kwargs))
#
#   File ~/work/peak/peak/family.py:144 in deco
#     cls.__call__ = apply_passes(self._passes, env=env)(cls.__call__)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/util.py:225 in __call__
#     args = p(args)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/base.py:20 in __call__
#     return self.rewrite(*args)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/ssa.py:728 in rewrite
#     tree = tree.visit(ssa_transformer)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:237 in visit
#     leave_result = visitor.on_leave(self, with_updated_children)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/transformers/node_tracker.py:25 in on_leave
#     final_node = super().on_leave(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_visitors.py:71 in on_leave
#     updated_node = leave_func(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/ssa.py:400 in leave_FunctionDef
#     new_body = updated_node.body.visit(self)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/statement.py:698 in _visit_and_replace_children
#     body=visit_body_sequence(self, "body", self.body, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:227 in visit_body_sequence
#     return tuple(visit_body_iterable(parent, fieldname, children, visitor))
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:193 in visit_body_iterable
#     new_child = child.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:237 in visit
#     leave_result = visitor.on_leave(self, with_updated_children)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/transformers/node_tracker.py:25 in on_leave
#     final_node = super().on_leave(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_visitors.py:71 in on_leave
#     updated_node = leave_func(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/ssa.py:425 in leave_If
#     new_body = updated_node.body.visit(self)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/statement.py:698 in _visit_and_replace_children
#     body=visit_body_sequence(self, "body", self.body, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:227 in visit_body_sequence
#     return tuple(visit_body_iterable(parent, fieldname, children, visitor))
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:193 in visit_body_iterable
#     new_child = child.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/statement.py:443 in _visit_and_replace_children
#     body=visit_sequence(self, "body", self.body, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:177 in visit_sequence
#     return tuple(visit_iterable(parent, fieldname, children, visitor))
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:159 in visit_iterable
#     new_child = child.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:237 in visit
#     leave_result = visitor.on_leave(self, with_updated_children)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/transformers/node_tracker.py:25 in on_leave
#     final_node = super().on_leave(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_visitors.py:71 in on_leave
#     updated_node = leave_func(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/ssa.py:507 in leave_Assign
#     new_value = updated_node.value.visit(self)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/expression.py:2357 in _visit_and_replace_children
#     args=visit_sequence(self, "args", self.args, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:177 in visit_sequence
#     return tuple(visit_iterable(parent, fieldname, children, visitor))
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:159 in visit_iterable
#     new_child = child.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/expression.py:2169 in _visit_and_replace_children
#     value=visit_required(self, "value", self.value, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:81 in visit_required
#     result = node.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/expression.py:3515 in _visit_and_replace_children
#     elt=visit_required(self, "elt", self.elt, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:81 in visit_required
#     result = node.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/expression.py:1576 in _visit_and_replace_children
#     slice=visit_sequence(self, "slice", self.slice, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:177 in visit_sequence
#     return tuple(visit_iterable(parent, fieldname, children, visitor))
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:159 in visit_iterable
#     new_child = child.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/expression.py:1521 in _visit_and_replace_children
#     slice=visit_required(self, "slice", self.slice, visitor),
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:81 in visit_required
#     result = node.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:228 in visit
#     _CSTNodeSelfT, self._visit_and_replace_children(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/expression.py:1442 in _visit_and_replace_children
#     return Index(value=visit_required(self, "value", self.value, visitor))
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/internal.py:81 in visit_required
#     result = node.visit(visitor)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_nodes/base.py:237 in visit
#     leave_result = visitor.on_leave(self, with_updated_children)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/transformers/node_tracker.py:25 in on_leave
#     final_node = super().on_leave(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/libcst/_visitors.py:71 in on_leave
#     updated_node = leave_func(original_node, updated_node)
#
#   File ~/work/peak-tutorial/env-peak-tutorial/lib/python3.10/site-packages/ast_tools/passes/ssa.py:561 in leave_Name
#     raise SyntaxError(f'Cannot prove name `{name}` is defined')
#
#   File <string>
# SyntaxError: Cannot prove name `idx` is defined

# %%
from ast_tools.passes import if_inline

def alugen(op_map, num_ports, datawidth, use_valid):
    assert op_map  # len(op_map) > 0
    Opcode = type(Enum)('Opcode', (Enum, ), {k: Enum.Auto() for k in op_map})

    @family_closure
    def ALU_fc(family):
        Word = family.BitVector[datawidth]
        Bit = family.Bit
        ts = [Word for _ in range(num_ports)]
        if use_valid:
            ts.append(Bit)

        if use_valid:
            out_t = Word, Bit
        else:
            out_t = Word

        T = family.get_constructor(Tuple[ts])
        op_names = list(reversed(op_map))

        def build_args(inputs, op_indices):
            return (inputs[idx] for idx in op_indices)

        @family.assemble(locals(), globals())
        class ALU(Peak):
            @apply_passes([loop_unroll(), if_inline()])
            def __call__(self, inst: Opcode, inputs: T) -> out_t:
                op_name = op_names[0]
                f, op_indices = op_map[op_name]
                op_enum = getattr(Opcode, op_name)
                res = f(*build_args(inputs, op_indices))

                for i in ast_tools.macros.unroll(range(1, len(op_names))):
                    op_name = op_names[i]
                    f, op_indices = op_map[op_name]
                    op_enum = getattr(Opcode, op_name)
                    if op_enum == inst:
                        res = f(*build_args(inputs, op_indices))
                        
                if ast_tools.macros.inline(use_valid):
                    if ~inputs[-1]:
                        res = Word(0)
                    valid_out = inputs[-1] # valid_in
                    return res, valid_out
                else:
                    return res

        return ALU

    return Opcode, ALU_fc


def add3(a, b, c):
    return a + b + c


def sub(a, b):
    return a - b


def neg(a):
    return -a


NUM_INPUTS = 3
DATA_WIDTH = 16

OP_MAP = {
    'Add': (add3, (0, 1, 2)),
    'Sub': (sub, (0, 2)),
    'Neg': (neg, (1, )),
}

USE_VALID = True

Opcode, ALU_fc = alugen(OP_MAP, NUM_INPUTS, DATA_WIDTH, USE_VALID)

assert hasattr(Opcode, 'Add')
assert hasattr(Opcode, 'Sub')
assert hasattr(Opcode, 'Neg')

DataT = Tuple[hw.BitVector[16], hw.BitVector[16], hw.BitVector[16], hw.Bit]

ALU = ALU_fc.Py
alu = ALU()

for _ in range(256):
    a = hw.BitVector.random(16)
    b = hw.BitVector.random(16)
    c = hw.BitVector.random(16)
    valid_in = hw.BitVector.random(1)[0]
    inputs = DataT(a, b, c, valid_in)
    if valid_in:
        assert alu(Opcode.Add, inputs) == (a + b + c, hw.Bit(1))
        assert alu(Opcode.Sub, inputs) == (a - c, hw.Bit(1))
        assert alu(Opcode.Neg, inputs) == (-b, hw.Bit(1))
    else:
        assert alu(Opcode.Add, inputs) == (hw.BitVector[16](0), hw.Bit(0))
        assert alu(Opcode.Sub, inputs) == (hw.BitVector[16](0), hw.Bit(0))
        assert alu(Opcode.Neg, inputs) == (hw.BitVector[16](0), hw.Bit(0))
